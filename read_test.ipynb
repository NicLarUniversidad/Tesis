# %%
import pandas as pd
import json
import ast

# %%
file_name = "results-baseline_00_00_00_deepseek-coder-33b-instruct.csv"

# %%
dataset = pd.read_csv(file_name, sep="\t")
dataset
# Out:
#    Prompt-ID                                             Prompt  \
# 0          0  abre el libro y retorna el marcador con la pag...
# 1          1  set the name of the catalog to be seached , or...
# 2          2   get the docker rest uri\n\n Write a code in java
# 3          3  gets all codecs which can decode the specified...
# 4          4  get the specified section\n\n Write a code in ...
# 5          5    random node form group\n\n Write a code in java
# 6          6  transforms the input to result by executing a ...
# 7          7  logs the given exception using the platform 's...
# 8          8  get the value of one of the fields of a dateti...
# 9          9  create and cache a new recording debug info st...
#
#                                             Baseline  \
# 0  int function ( ) { return this . getMarcador (...
# 1  void function ( String arg0 ) { this . catalog...
# 2                  URI function ( ) { return uri ; }
# ...

# %%
dataset['CodeBleuScore_Real'] = dataset['CodeBleuScore'].apply(lambda x: json.loads(x).get('codebleu'))
df['valor_extraido'] = df['datos_json'].apply(lambda x: ast.literal_eval(x).get('valor'))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dataset['CodeBleuScore_Real'] = dataset['CodeBleuScore'].apply(lambda x: json.loads(x).get('codebleu'))
#
# File c:\Users\Rikudo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# ...
